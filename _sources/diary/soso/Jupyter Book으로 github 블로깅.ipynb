# %% [markdown]
# # Jupyter Book으로 github 블로깅
#
# https://jupyterbook.org/start/your-first-book.html
#
# example을 잘 따라 실행하면 자동으로 juypter notebook 을 빌드 시켜주는 페이지를 생성할 수 있다!
# 이걸 github.io에 실행시켜주려면 workflow에서 action을 통해서 CI/CD 빌드 시켜주면 된다.
# gh-pages를 통해서 실행된 브랜치를 github.io에서 읽도록 적용시켜주면 끝!
